# %%
import data_acquisition as da
import constants as cs

# %%
da.generate_test_csv(cs.FLIGHT_TESTS.B106)
# Out:
# Create csv files for the flight test B106: 100%|██████████| 61/61 [48:12<00:00, 47.42s/file]

# %%
da.generate_test_csv(cs.FLIGHT_TESTS.B109)
# Out:
# Create csv files for the flight test B109: 100%|██████████| 61/61 [48:35<00:00, 47.79s/file]

# %%
da.generate_tests_csv()
# Out:
# ...
# Create csv files for the flight test B109: 100%|██████████| 2/2 [01:36<00:00, 48.03s/file]

# %%
flight_tests = da.generate_flight_tests()

# %%
flight_tests[0].get_id()
# Out:
# 'B101'

# %%
flight_tests[0].get_timeseries()
# Out:
# '../timeseries/B101'

# %%
print(flight_tests[0])
print(flight_tests[1])
print(flight_tests[2])
# Out:
# FlightTest(ID=B101, Version=5, NumberOfValues=12288000, Channels=62, BlockSize=32768, ProcMethod=Baseband, AcqMode=Continuous, CenterFrequency=0, Span=92876.8, SampleInterval=4.8828125e-06, PercentRealTime=100, Date=0/0/0, Time=0:0:0, ScaleFactors=[269.4472508142742, 269.23902721010654, 268.6511498593608, 269.0829488106922, 268.77141361431535, 269.0549068256384, 268.8658419973023, 269.3260165946646, 268.9167294266537, 267.98551128164837, 268.74619226769084, 269.2093426303528, 269.4402980027607, 269.65412960207857, 268.8376176531548, 269.4313199645625, 268.9773608147465, 268.9526471027226, 269.2861626694653, 269.205647129561, 269.09744613452835, 269.23042348560904, 268.79765547250054, 269.35560260620383, 268.907680622759, 269.73500501768837, 269.33930663549694, 268.94303436525865, 268.9596219372101, 269.18085318493075, 269.63796064651024, 269.19632372418414, 268.86056979935165, 269.38294493568657, 269.00909622177454, 268.4073625815897, 269.3687951946393, 271.63837342866475, 269.279317
# ...
