# %%
from CrossSensors import CrossSensors
import data_acquisition as da
from IPython.display import display

# %%
microphones = da.generate_microphones()

# %%
microphones[0].to_dataframe()
# Out:
#    id  name  x  y  dx  dy      p     q
# 0   1  F001  0  0   3   0 -160.0  90.0

# %%
cross_sensors = CrossSensors(microphones)

# %%
print(cross_sensors)
# Out:
# CrossSensors(microphones=[Microphone(1, F001, 0, 0, 3, 0, -160.0, 90.0), Microphone(2, F002, 3, 0, 3, 0, -157.02, 89.63), Microphone(3, F003, 6, 0, 3, 0, -154.04, 89.27), Microphone(4, F004, 9, 0, 3, 0, -151.07, 88.9), Microphone(5, F005, 12, 0, 3, 0, -148.09, 88.54), Microphone(6, F006, 15, 0, 3, 0, -145.11, 88.17), Microphone(7, F007, 18, 0, 3, 0, -142.13, 87.81), Microphone(8, F008, 21, 0, 3, 0, -139.16, 87.44), Microphone(9, F009, 24, 0, 3, 0, -136.18, 87.08), Microphone(10, F010, 27, 0, 3, 0, -133.2, 86.71), Microphone(11, F011, 30, 0, 3, 0, -130.22, 86.34), Microphone(12, F012, 33, 0, 3, 0, -127.25, 85.98), Microphone(13, F013, 36, 0, 3, 0, -124.27, 85.61), Microphone(14, F014, 39, 0, 3, 0, -121.29, 85.25), Microphone(15, F015, 42, 0, 3, 0, -118.31, 84.88), Microphone(16, F016, 45, 0, 3, 0, -115.34, 84.52), Microphone(17, F017, 48, 0, 3, 0, -112.36, 84.15), Microphone(18, F018, 51, 0, 3, 0, -109.38, 83.78), Microphone(19, F019, 54, 0, 3, 0, -106.4, 83.42), Microphone(20, F020, 
# ...

# %%
cross_sensors.plot_sensors()

# %%
display(cross_sensors.to_dataframe())
# Out:
#     id   name    x   y  dx  dy       p       q
# 0    1   F001    0   0   3   0 -160.00   90.00
# 1    2   F002    3   0   3   0 -157.02   89.63
# 2    3   F003    6   0   3   0 -154.04   89.27
# 3    4   F004    9   0   3   0 -151.07   88.90
# 4    5   F005   12   0   3   0 -148.09   88.54
# 5    6   F006   15   0   3   0 -145.11   88.17
# 6    7   F007   18   0   3   0 -142.13   87.81
# 7    8   F008   21   0   3   0 -139.16   87.44
# 8    9   F009   24   0   3   0 -136.18   87.08
# 9   10   F010   27   0   3   0 -133.20   86.71
# 10  11   F011   30   0   3   0 -130.22   86.34
# 11  12   F012   33   0   3   0 -127.25   85.98
# 12  13   F013   36   0   3   0 -124.27   85.61
# 13  14   F014   39   0   3   0 -121.29   85.25
# 14  15   F015   42   0   3   0 -118.31   84.88
# 15  16   F016   45   0   3   0 -115.34   84.52
# 16  17   F017   48   0   3   0 -112.36   84.15
# 17  18   F018   51   0   3   0 -109.38   83.78
# 18  19   F019   54   0   3   0 -106.40   83.42
# ...
