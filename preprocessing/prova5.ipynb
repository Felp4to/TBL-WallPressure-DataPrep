# %%
import data_analysis as da

# %%
da.plot_timeseries("../timeseries/B101/Channel1.csv", 1000)

# %%
# Esempio di utilizzo
period = da.estimate_period_from_fft("../timeseries/B101/Channel1.csv", 10000)
print(f"Periodo stimato: {period}")
# Out:
# Periodo stimato: None
