# %%
from mat4py import loadmat
import constants as cs

# %%
data = loadmat(cs.CHANNEL_1_PATH)
display(data)
# Out:
# {'singleData': [-21702628.0,
#   -8657071.0,
#   7671702.0,
#   14368814.0,
#   17132264.0,
#   19591510.0,
#   16921288.0,
#   22267390.0,
#   28665146.0,
#   39199188.0,
#   45872856.0,
#   43316880.0,
#   36802184.0,
#   35882828.0,
#   46032100.0,
#   50117460.0,
#   47670068.0,
#   40014532.0,
#   31213578.0,
#   22782304.0,
#   12815989.0,
#   7562576.0,
#   728854.8125,
#   -10202620.0,
#   -16891918.0,
#   -18561952.0,
#   -20141990.0,
#   -25326156.0,
#   -28899296.0,
#   -31613438.0,
#   -28717958.0,
#   -25322652.0,
#   -31721756.0,
#   -34160252.0,
#   -39258464.0,
#   -41083700.0,
#   -44022560.0,
#   -38885820.0,
#   -28585928.0,
#   -18404864.0,
#   -3572870.5,
#   12303231.0,
#   27226028.0,
#   39519020.0,
#   48424520.0,
#   57251076.0,
#   53950884.0,
#   45269832.0,
#   38288992.0,
#   26329846.0,
#   17062748.0,
#   12256078.0,
#   6125883.0,
#   6700075.5,
#   10066549.0,
#   16032650.0,
#   32070960.0,
#   46703292.0,
#   57622912.0,
#   63482312.0,
# ...

# %%
display(len(data['singleData']))
# Out:
# 12287999

# %%
data = loadmat(cs.CHANNEL_2_PATH)
display(data)
# Out:
# {'singleData': [-21702628.0,
#   -8657071.0,
#   7671702.0,
#   14368814.0,
#   17132264.0,
#   19591510.0,
#   16921288.0,
#   22267390.0,
#   28665146.0,
#   39199188.0,
#   45872856.0,
#   43316880.0,
#   36802184.0,
#   35882828.0,
#   46032100.0,
#   50117460.0,
#   47670068.0,
#   40014532.0,
#   31213578.0,
#   22782304.0,
#   12815989.0,
#   7562576.0,
#   728854.8125,
#   -10202620.0,
#   -16891918.0,
#   -18561952.0,
#   -20141990.0,
#   -25326156.0,
#   -28899296.0,
#   -31613438.0,
#   -28717958.0,
#   -25322652.0,
#   -31721756.0,
#   -34160252.0,
#   -39258464.0,
#   -41083700.0,
#   -44022560.0,
#   -38885820.0,
#   -28585928.0,
#   -18404864.0,
#   -3572870.5,
#   12303231.0,
#   27226028.0,
#   39519020.0,
#   48424520.0,
#   57251076.0,
#   53950884.0,
#   45269832.0,
#   38288992.0,
#   26329846.0,
#   17062748.0,
#   12256078.0,
#   6125883.0,
#   6700075.5,
#   10066549.0,
#   16032650.0,
#   32070960.0,
#   46703292.0,
#   57622912.0,
#   63482312.0,
# ...

# %%
display(len(data['singleData']))
# Out:
# 12287999
