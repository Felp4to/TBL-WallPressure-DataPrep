# %%
import os
import sys
sys.path.append("./npy")
import utilities as utilities
import spectrogram as spectrogram

# %%
filename = "Channel1.csv"
file_path = os.path.join("../timeseries/B101", filename)

# %%
time_series = utilities.load_time_series(file_path)
print(time_series)
print(time_series.shape)
# Out:
# [-21702628.   -8657071.    7671702.  ...  -7847381.5  24490868.
#   41916832. ]
# (12287999,)

# %%
# Calcolare lo spettrogramma
f, t, Sxx = spectrogram.compute_spectogram(time_series[:2000], 256, 0, True)
print(Sxx.shape)
# Out:
# (129, 7)
