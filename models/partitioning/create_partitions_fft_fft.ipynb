# %%
import os
import sys
import json
import partitioning as part
sys.path.append("../preprocessing/npy")
import sampling as samp
import normalizzation as norm
import dft as dft
sys.path.append("../utilities")
import loadData as loadData

# %%
file_config_name = "configs_fft_fft.json"
filename = "Channel1.csv"
file_path = os.path.join("../timeseries/B101", filename)

# %%
configs = None

# Apri il file e carica i dati in una variabile
with open(file_config_name, "r") as f:
    configs = json.load(f)

# Ora configs contiene tutte le configurazioni
print("Configurazioni caricate:")
for name, conf in configs.items():
    print(f"{name}: id = {conf['id']}")
# Out:
# Configurazioni caricate:
# config_1: id = 1
# config_2: id = 2
# config_3: id = 3
# config_4: id = 4
# config_5: id = 5
# config_6: id = 6
# config_7: id = 7
# config_8: id = 8
# config_9: id = 9
# config_10: id = 10
# config_11: id = 11
# config_12: id = 12

# %%
for name, config in configs.items():
    foldername = "part_fft_fft_" + str(config["id"])

    # slicing and sampling
    sliced_and_sampled_data = samp.sampling_csv(samp.slicing(file_path, config["dim_slice"]), config["sampling"])
    sliced_and_sampled_data.reset_index(drop=True, inplace=True)

    # normalizzation
    time_series_normalized = norm.normalize_array(sliced_and_sampled_data)
    #display(time_series_normalized)

    # generazione delle sequenze
    X, y = part.generate_fft_sequences_with_frequency_target(time_series_normalized, config)

    # split delle partizioni
    part.split_and_save_dataset(X, y, foldername, config)
# Out:
# Shape di X: (1454, 320)
# Shape di y: (1454, 32)
# Totale campioni: 1454
# Train set: X = (1017, 320), y = (1017, 32)
# Validation set: X = (218, 320), y = (218, 32)
# Test set: X = (219, 320), y = (219, 32)
#
# ✅ Partizioni create e salvate in 'partitions/part_fft_fft_1'
# Shape di X: (761, 640)
# Shape di y: (761, 32)
# Totale campioni: 761
# Train set: X = (532, 640), y = (532, 32)
# Validation set: X = (114, 640), y = (114, 32)
# Test set: X = (115, 640), y = (115, 32)
#
# ✅ Partizioni create e salvate in 'partitions/part_fft_fft_2'
# Shape di X: (313, 1600)
# Shape di y: (313, 32)
# Totale campioni: 313
# Train set: X = (219, 1600), y = (219, 32)
# Validation set: X = (46, 1600), y = (46, 32)
# Test set: X = (48, 1600), y = (48, 32)
#
# ✅ Partizioni create e salvate in 'partitions/part_fft_fft_3'
# Shape di X: (158, 3200)
# Shape di y: (158, 32)
# Totale campioni: 158
# Train set: X = (110, 3200), y = (110, 32)
# Validation set: X = (23, 3200), y = (23, 32)
# Test set: X = (25, 3200), y = (25, 32)
#
# ✅ Partizioni create e salvate in 'partitions/part_fft_fft_4'
# Shape di X: (79, 6400)
# Shape di y: (79, 32)
# Totale campioni: 79
# Train set: X = (55, 6400), y = (55, 32)
# Validation set: X = (11, 6400), y = (11, 32)
# Test set: X = (13, 6400), y = (13, 32)
#
# ✅ Partizioni create e salvate in 'partitions/part_fft_fft_5'
# Shape di X: (380, 1280)
# Shape di y: (380, 64)
# Totale campioni: 380
# Train set: X = (266, 1280), y = (266, 64)
# Validation set: X = (57, 1280), y = (57, 64)
# Test set: X = (57, 1280), y = (57, 64)
#
# ✅ Partizioni create e salvate in 'partitions/part_fft_fft_6'
# Shape di X: (190, 2560)
# Shape di y: (190, 128)
# Totale campioni: 190
# Train set: X = (133, 2560), y = (133, 128)
# Validation set: X = (28, 2560), y = (28, 128)
# Test set: X = (29, 2560), y = (29, 128)
#
# ✅ Partizioni create e salvate in 'partitions/part_fft_fft_7'
# Shape di X: (126, 3840)
# Shape di y: (126, 192)
# Totale campioni: 126
# Train set: X = (88, 3840), y = (88, 192)
# Validation set: X = (18, 3840), y = (18, 192)
# Test set: X = (20, 3840), y = (20, 192)
#
# ✅ Partizioni create e salvate in 'partitions/part_fft_fft_8'
# Shape di X: (1523, 320)
# Shape di y: (1523, 16)
# Totale campioni: 1523
# Train set: X = (1066, 320), y = (1066, 16)
# Validation set: X = (228, 320), y = (228, 16)
# Test set: X = (229, 320), y = (229, 16)
#
# ✅ Partizioni create e salvate in 'partitions/part_fft_fft_9'
# Shape di X: (3047, 160)
# Shape di y: (3047, 8)
# Totale campioni: 3047
# Train set: X = (2132, 160), y = (2132, 8)
# Validation set: X = (457, 160), y = (457, 8)
# Test set: X = (458, 160), y = (458, 8)
#
# ✅ Partizioni create e salvate in 'partitions/part_fft_fft_10'
# Shape di X: (1272, 640)
# Shape di y: (1272, 32)
# Totale campioni: 1272
# Train set: X = (890, 640), y = (890, 32)
# Validation set: X = (190, 640), y = (190, 32)
# Test set: X = (192, 640), y = (192, 32)
#
# ✅ Partizioni create e salvate in 'partitions/part_fft_fft_11'
# Shape di X: (3816, 640)
# Shape di y: (3816, 32)
# Totale campioni: 3816
# Train set: X = (2671, 640), y = (2671, 32)
# Validation set: X = (572, 640), y = (572, 32)
# Test set: X = (573, 640), y = (573, 32)
#
# ✅ Partizioni create e salvate in 'partitions/part_fft_fft_12'
